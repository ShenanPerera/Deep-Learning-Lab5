# %% [markdown]
# # **Task 1 - Implement a Simple RNN to Predict the Next Value in a Small Sequence of Numbers**
#
# ***Read the following descriptions and instructions***
#
# In time-series analysis, predicting future values based on past observations is a fundamental task. Recurrent Neural Networks (RNNs) are particularly well-suited for this type of problem due to their ability to maintain a memory of previous inputs through their recurrent connections.
#
# In this task, you will work with a synthetic dataset that represents a simple sine wave. The sine wave is a periodic function and serves as a good example to understand how RNNs can capture patterns and make predictions.
#
# A **sine wave** is a fundamental waveform that is widely used in various fields, including signal processing, physics, and time-series analysis. It is characterized by its smooth, periodic oscillations, making it an ideal example for understanding time-series prediction tasks.![11.jpg](data:image/jpeg;base64,...)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# %% [markdown]
# The generate_sine_wave function generates a synthetic sine wave dataset, which is often used in time-series prediction tasks, particularly for training models like RNNs and LSTMs.
#
#
# **seq_length=100**: This parameter is intended to specify the length of the sequence that you want to generate
#
# **num_samples=1000**:This parameter determines the number of data points (samples) to generate for the sine wave.

# %%
# 1. Generate a Synthetic Sine Wave Dataset
def generate_sine_wave(seq_length=100, num_samples=1000):
    x = np.linspace(0, 50, num_samples)
    y = np.sin(x)
    return y

# %% [markdown]
# The create_dataset function prepares the sine wave data for use in an RNN by converting the continuous data into sequences that the RNN can learn from. The time_step parameter in the create_dataset function represents the number of previous time points (or observations) that are used as input to predict the next time point in a sequence.

# %%
# 2. Prepare the Dataset for RNN
def create_dataset(data, time_step=10):
    X, y = [], []
    for i in range(len(data) - time_step - 1):
        X.append(data[i:(i + time_step)])
        y.append(data[i + time_step])
    return np.array(X), np.array(y)

# %% [markdown]
# To prepare the data for modeling, it is important to normalize it so that all values fall within a specific range, typically between 0 and 1. This step improves the performance and convergence of neural network models.
#
# The MinMaxScaler from sklearn.preprocessing is used for this purpose. It scales the data such that the minimum value of the data becomes 0 and the maximum value becomes 1.
#
# The sine wave data is reshaped into a 2D array (-1, 1) to fit the scaler, as it expects a 2D input. After scaling, the data is reshaped back into its original 1D form.

# %%
# Generate and Normalize the Data
data = generate_sine_wave()
scaler = MinMaxScaler(feature_range=(0, 1))
data = scaler.fit_transform(data.reshape(-1, 1)).reshape(-1)

# %%
# Create the Dataset
time_step = 10  # Time steps for RNN input
X, y = create_dataset(data, time_step)

# %%
# Reshape for RNN input [samples, time steps, features]
X = X.reshape(X.shape[0], X.shape[1], 1)

# %% [markdown]
# This division of data helps in evaluating the model’s performance by training it on a substantial portion of the data and testing its predictions on unseen data.

# %%
# Split the Data into Training and Testing Sets (80% train, 20% test)
train_size = int(len(X) * 0.8)
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

# %% [markdown]
# ***Modify the units parameter in the SimpleRNN layer to see how the number of hidden units affects the model's ability to learn the sequence.***
#
#
# **optimizer='adam':** Uses the Adam optimizer, which is a popular choice for training deep learning models due to its adaptive learning rate.
#
#
# **loss='mean_squared_error':** Sets the loss function to mean squared error (MSE), which is commonly used for regression tasks to measure the average squared difference between predicted and actual values.

# %%
# 3. Define the RNN Model
model = Sequential()
model.add(SimpleRNN(units=15, return_sequences=False, input_shape=(time_step, 1)))  # <-- Tune 'units'
model.add(Dense(1))
model.compile(optimizer='adam', loss='mean_squared_error')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# ***Adjust the epochs and batch_size during the training phase to optimize the model's learning process and performance.***
#
# an
#
# **epochs=20:** Specifies the number of times the entire training dataset will pass through the model.
#
#
# **batch_size=32:** Determines the number of samples per gradient update.
#
# **verbose=1:** Provides detailed output during training, including the progress of each epoch and loss values.

# %% [markdown]
# #Baseline model

# %%
# 4. Train the Model
model.fit(X_train, y_train, epochs=30, batch_size=32, verbose=1)  # <-- Experiment with 'epochs' and 'batch_size'
# Out:
# Epoch 1/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.8286
# Epoch 2/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0815
# Epoch 3/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0412
# Epoch 4/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0193
# Epoch 5/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0095
# Epoch 6/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0059
# Epoch 7/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0046
# Epoch 8/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0042
# Epoch 9/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0040
# Epoch 10/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0036
# Epoch 11/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0035
# Epoch 12/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0032
# Epoch 13/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0030
# Epoch 14/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0027
# Epoch 15/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0026
# Epoch 16/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0024
# Epoch 17/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0022
# Epoch 18/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0020
# Epoch 19/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019
# Epoch 20/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0018
# Epoch 21/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017
# Epoch 22/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0015
# Epoch 23/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0014
# Epoch 24/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0013
# Epoch 25/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0011
# Epoch 26/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0011
# Epoch 27/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.7523e-04
# Epoch 28/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 9.5689e-04
# Epoch 29/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.4765e-04
# Epoch 30/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.7947e-04

# %% [markdown]
# #model for hidden units

# %%
hidden_unit_model = Sequential()
hidden_unit_model.add(SimpleRNN(units=1, return_sequences=False, input_shape=(time_step, 1)))  # <-- Tune 'units'
hidden_unit_model.add(Dense(1))
hidden_unit_model.compile(optimizer='adam', loss='mean_squared_error')

# %%
# 4. Train the Model
hidden_unit_model.fit(X_train, y_train, epochs=30, batch_size=32, verbose=1)  # <-- Experiment with 'epochs' and 'batch_size'
# Out:
# Epoch 1/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.5990
# Epoch 2/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5053
# Epoch 3/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4882
# Epoch 4/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4332
# Epoch 5/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3647
# Epoch 6/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3387
# Epoch 7/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3043
# Epoch 8/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.2657
# Epoch 9/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2213
# Epoch 10/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2104
# Epoch 11/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1665
# Epoch 12/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1601
# Epoch 13/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1415
# Epoch 14/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1241
# Epoch 15/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1166
# Epoch 16/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1072
# Epoch 17/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1034
# Epoch 18/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0956
# Epoch 19/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0832
# Epoch 20/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0828
# Epoch 21/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0747
# Epoch 22/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0714
# Epoch 23/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0675
# Epoch 24/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0697
# Epoch 25/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0630
# Epoch 26/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0626
# Epoch 27/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0584
# Epoch 28/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0592
# Epoch 29/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0583
# Epoch 30/30
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0590

# %% [markdown]
# #model for epochs

# %%
epoch_model = Sequential()
epoch_model.add(SimpleRNN(units=15, return_sequences=False, input_shape=(time_step, 1)))  # <-- Tune 'units'
epoch_model.add(Dense(1))
epoch_model.compile(optimizer='adam', loss='mean_squared_error')

# %%
# 4. Train the Model
epoch_model.fit(X_train, y_train, epochs=10, batch_size=32, verbose=1)  # <-- Experiment with 'epochs' and 'batch_size'
# Out:
# Epoch 1/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.1761
# Epoch 2/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0180
# Epoch 3/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0090
# Epoch 4/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0047
# Epoch 5/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0026
# Epoch 6/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0019
# Epoch 7/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0017
# Epoch 8/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0016
# Epoch 9/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0014
# Epoch 10/10
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0013

# %% [markdown]
# #model for bactch_size

# %%
batch_size_model = Sequential()
batch_size_model.add(SimpleRNN(units=15, return_sequences=False, input_shape=(time_step, 1)))  # <-- Tune 'units'
batch_size_model.add(Dense(1))
batch_size_model.compile(optimizer='adam', loss='mean_squared_error')

# %%
# 4. Train the Model
batch_size_model.fit(X_train, y_train, epochs=30, batch_size=12, verbose=1)  # <-- Experiment with 'epochs' and 'batch_size'
# Out:
# Epoch 1/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.4248
# Epoch 2/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.0104
# Epoch 3/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.0042
# Epoch 4/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0020
# Epoch 5/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0012
# Epoch 6/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0010
# Epoch 7/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.5050e-04
# Epoch 8/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.4725e-04
# Epoch 9/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.3962e-04
# Epoch 10/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.5732e-04
# Epoch 11/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 6.3486e-04
# Epoch 12/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.7271e-04
# Epoch 13/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.4050e-04
# Epoch 14/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.9880e-04
# Epoch 15/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.1515e-04
# Epoch 16/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 3.9059e-04
# Epoch 17/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 3.7352e-04
# Epoch 18/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1716e-04
# Epoch 19/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8784e-04
# Epoch 20/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5683e-04
# Epoch 21/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3416e-04
# Epoch 22/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0704e-04
# Epoch 23/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8528e-04
# Epoch 24/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7481e-04
# Epoch 25/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6558e-04
# Epoch 26/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.4498e-04
# Epoch 27/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1722e-04
# Epoch 28/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0785e-04
# Epoch 29/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0701e-04
# Epoch 30/30
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.3410e-05

# %%
# 5. Predict on the Test Data
y_pred = model.predict(X_test)
y_pred_hidden_unit = hidden_unit_model.predict(X_test)
y_pred_epoch = epoch_model.predict(X_test)
y_pred_batch_size = batch_size_model.predict(X_test)
# Out:
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# WARNING:tensorflow:5 out of the last 15 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7e308ebd2f80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# WARNING:tensorflow:5 out of the last 15 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7e308e9f1240> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step

# %% [markdown]
# These steps reverse the normalization applied earlier to the predictions and actual values. Normalization scales the data to a range, typically [0, 1], which helps with model training but makes the results difficult to interpret directly.
# By applying the inverse transformation, you convert the scaled predictions (y_pred) and test values (y_test) back to their original scale, allowing you to evaluate and visualize the model's performance in the context of the original data values.

# %%
# Inverse transform to get the original scale (if normalization was applied)
y_pred = scaler.inverse_transform(y_pred.reshape(-1, 1)).reshape(-1)
y_pred_hidden_unit = scaler.inverse_transform(y_pred_hidden_unit.reshape(-1, 1)).reshape(-1)
y_pred_epoch = scaler.inverse_transform(y_pred_epoch.reshape(-1, 1)).reshape(-1)
y_pred_batch_size = scaler.inverse_transform(y_pred_batch_size.reshape(-1, 1)).reshape(-1)
y_test = scaler.inverse_transform(y_test.reshape(-1, 1)).reshape(-1)

# %% [markdown]
# This plot visually compares the actual sine wave values (y_test) with the values predicted by the RNN model (y_pred).
#
# By plotting both sets of values on the same graph, you can easily see how well the model's predictions align with the actual data.
#
# This visualization helps in assessing the performance of the RNN model and understanding how accurately it captures the underlying pattern in the time series data.
#
# ***Analyze the resulting plot. If the predicted values deviate significantly from the actual values, experiment with different model configurations and training parameters to improve accuracy.***
#
# # **Describe your observations. You can add a text cell and type your observations.**

# %%
# 6. Plot the Results
plt.figure(figsize=(12, 6))
plt.plot(y_test, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.plot(y_pred_hidden_unit, label='Predicted_hidden_unit')
plt.plot(y_pred_epoch, label='Predicted_epoch')
plt.plot(y_pred_batch_size, label='Predicted_batch_size')
plt.xlabel('Time Steps')
plt.ylabel('Value')
plt.title('RNN Prediction on Sine Wave')
plt.legend()
plt.show()

# %% [markdown]
# #Observations
#
# There is no large deviation with epochs and batch size.But it deviates when the hidden layers decrease as seen according to the above modified graph.
